# %% [markdown]
# # From proPTV to OpenPTV
#
# Let us imagine the following thought experiment. Robin has performed a physical calibration using Soloff method. The only physical information available is the size of the image, several vectors of Soloff coefficients and particle images. Of course, proPTV is sufficient to convert those to the 3D positions and track them in time.
#
# What if another software can do something in addtion, e.g. track in 3D-2D space? Option 1 is to recode all the knowledge again for the proPTV. Option 2 is to create OpenPTV working folder with all the missing information, calibrate OpenPTV with the virtual scene created using proPTV and then use openPTV capabilities. For instance, OpenPTV has dumbbell or wand calibration, and MyPTV has an extended Soloff method.
#
# OpenPTV can be calibrated in one of the two ways, depending on the available or reliable assumption of the physical setup: a) using single homogeneous media approximation, ``all-in-air'' with $n_1 = n_2 = n_3 = 1$ and then it would be roughly the simple Tsai model with aberrations; b) use multi-media model $n_1 = 1, n_2 = 1.46, n_3 = 1.33$ and then we need additional physical information: glass thickness, water distance, parallel positioning of the target in respect to the glass window and so on.

# %%
# Implementation
# Create a 3D target, a list of 3D points well distributed across the 3d volume
# Create 2D projections of the 3D target on the cameras using proPTV 
# use 2D projections per cameras and 3D target positions along with the assumed parameters
# for the OpenPTV to create new calibration parameters
# compare the results using the 3D Line of Sight

# %%
# %load proPTV_to_OpenPTV.py
# %% [markdown]
# # From proPTV to OpenPTV
# 
# Let us imagine the following thought experiment. Robin has performed a physical calibration using Soloff method. The only physical information available is the size of the image, several vectors of Soloff coefficients and particle images. Of course, proPTV is sufficient to convert those to the 3D positions and track them in time. 
# 
# What if another software can do something in addtion, e.g. track in 3D-2D space? Option 1 is to recode all the knowledge again for the proPTV. Option 2 is to create OpenPTV working folder with all the missing information, calibrate OpenPTV with the virtual scene created using proPTV and then use openPTV capabilities. For instance, OpenPTV has dumbbell or wand calibration, and MyPTV has an extended Soloff method. 
# 
# OpenPTV can be calibrated in one of the two ways, depending on the available or reliable assumption of the physical setup: a) using single homogeneous media approximation, ``all-in-air'' with $n_1 = n_2 = n_3 = 1$ and then it would be roughly the simple Tsai model with aberrations; b) use multi-media model $n_1 = 1, n_2 = 1.46, n_3 = 1.33$ and then we need additional physical information: glass thickness, water distance, parallel positioning of the target in respect to the glass window and so on. 
# 

# %%
# Implementation
# Create a 3D target, a list of 3D points well distributed across the 3d volume
# Create 2D projections of the 3D target on the cameras using proPTV 
# use 2D projections per cameras and 3D target positions along with the assumed parameters
# for the OpenPTV to create new calibration parameters
# compare the results using the 3D Line of Sight


# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib widget


# Create a linear space from 0 to 300 with 5 points in each direction
x = np.linspace(10, 290, 5)
y = np.linspace(10, 290, 5)
z = np.linspace(10, 290, 5)

# Create a 3D grid of points
X, Y, Z = np.meshgrid(x, y, z)


# %%
from openptv_python.tracking_frame_buf import TargetArray
from openptv_python.calibration import Calibration
from openptv_python.parameters import ControlPar, VolumePar, OrientPar, MultimediaPar
from openptv_python.orientation import full_calibration, external_calibration
from openptv_python.trafo import metric_to_pixel
from openptv_python.imgcoord import img_coord

# %%
import pathlib, os
working_path = pathlib.Path('OpenPTV_LineOfSight')

control_parameters = ControlPar().from_file(os.path.join(working_path,"parameters","ptv.par"))
volume_parameters = VolumePar().from_file(os.path.join(working_path,"parameters","criteria.par"))
orient_parameters = OrientPar()

# %%
# orient_parameters.scxflag = 1 # updated in the future version
# control_parameters.mm = MultimediaPar(nlay=1,n1=1., n2=[1.], d=[1.],n3=1.)

# %%

def openptv_project_XYZ_on_camera(XYZ, cal, cpar):
    """ Projects 3D points vector XYZ on camera defined by cal, cpar """
    xy = np.empty((XYZ.shape[0],2))
    for i, point in enumerate(XYZ):
        x, y = img_coord(point, cal, cpar.mm)
        x, y = metric_to_pixel(x, y, cpar)
        xy[i,0] = x
        xy[i,1] = y
    return xy

# %%
# %%
# Bring in proPTV data and functions
import sys
sys.path.append('proPTV_LineOfSight')
from func import F

calibration_path = "proPTV_LineOfSight/calibration/c{cam}/soloff_c{cam}{xy}.txt"
Vmin, Vmax = [0,0,0], [300,300,300]



# make 3D figure
axis = plt.figure(figsize=(5,5)).add_subplot(projection='3d')
axis.set_xlabel('X'), axis.set_ylabel('Y'), axis.set_zlabel('Z')
# plot box
axis.plot([0,300],[0,0],[0,0],c='black'), axis.plot([0,0],[0,300],[0,0],c='black'), axis.plot([0,0],[0,0],[0,300],c='black')
axis.plot([300,300],[0,300],[0,0],c='black'), axis.plot([300,300],[0,0],[0,300],c='black'), axis.plot([0,300],[300,300],[0,0],c='black')
axis.plot([0,0],[300,300],[0,300],c='black'), axis.plot([0,300],[0,0],[300,300],c='black'), axis.plot([0,0],[0,300],[300,300],c='black')
axis.plot([300,300],[300,300],[0,300],c='black'), axis.plot([300,300],[0,300],[300,300],c='black'), axis.plot([0,300],[300,300],[300,300],c='black')
# plot torus
axis.scatter(X, Y, Z, 'o', color='b')
# axis.plot(X_mid,Y_mid,Z_mid,'o-', color='red', linewidth=1)
# axis.plot(X_spiral,Y_spiral,Z_spiral,'o-', color='green', linewidth=1)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# make projection of lines in cam c
fig, axis = plt.subplots(2,2, figsize=(8,8))

for c in range(4):
    
    
    # load calibration of camera c
    ax, ay = np.loadtxt(calibration_path.format(cam=c,xy="x"),delimiter=','), \
            np.loadtxt(calibration_path.format(cam=c,xy="y"),delimiter=',')
    
    # Comment out when you have all calibration parameters
    # ax, ay = np.loadtxt(calibration_path.format(cam=c,xy="x"),delimiter=','), np.loadtxt(calibration_path.format(cam=c,xy="y"),delimiter=',')

    # estimate projection of the lines in camera c
    xy = np.vstack([F(np.vstack([X.flat,Y.flat,Z.flat]).T,ax),F(np.vstack([X.flat,Y.flat,Z.flat]).T,ay)]).T

    axis[int(c/2),c%2].set_title('reprojection on camera ' + str(c))
    axis[int(c/2),c%2].imshow(np.zeros([2160,2560]),cmap='gray')
    axis[int(c/2),c%2].plot(xy[:,0],xy[:,1],'+',c='white')


    openptv_camera_calibration = Calibration().from_file(os.path.join(working_path,"calibration",f"cam{c+1}.tif.ori"), None)
    

    all_known = np.c_[X.flat, Y.flat, Z.flat]
    all_detected = xy.copy()


    targs = TargetArray(len(all_detected))

    for tix in range(len(all_detected)):
        targ = targs[tix]
        det = all_detected[tix]

        targ.set_pnr(tix)
        targ.set_pos(det)


    # %%
    print(openptv_camera_calibration.ext_par, openptv_camera_calibration.int_par)

    # now we try to reset calibration and work from zero setup:

    openptv_camera_calibration = Calibration()
    openptv_camera_calibration.ext_par.x0 = 0
    openptv_camera_calibration.ext_par.y0 = 0
    openptv_camera_calibration.ext_par.z0 = 1000.0 # good initial guess

    openptv_camera_calibration.int_par.cc = 41.0 # nobody can guess
    
    # since we use multi-media, we better set the in-water distance
    # using glass vector
    openptv_camera_calibration.glass_par = np.array([0.0, 0.0, 300.0]) # 300 mm tank width

    print(f" Before: {openptv_camera_calibration.ext_par =}, {openptv_camera_calibration.int_par = }")


    # start with the simplest case: all in air:
    # control_parameters.mm = MultimediaPar(nlay=1,n1=1., n2=[1.], d=[1.],n3=1.)


    outcome = external_calibration(openptv_camera_calibration, all_known, all_detected, control_parameters)
    assert outcome is True
    

    print(f" After raw calibration: {openptv_camera_calibration.ext_par =}, {openptv_camera_calibration.int_par = }")

    xy_optv = openptv_project_XYZ_on_camera(np.vstack([X.flat,Y.flat,Z.flat]).T, openptv_camera_calibration, control_parameters)
    axis[int(c/2),c%2].plot(xy_optv[:,0],xy_optv[:,1],'x',c='red')


    # Run the multiplane calibration in full

    residuals, targ_ix, err_est = full_calibration(openptv_camera_calibration, all_known,
                                                    targs, control_parameters, orient_parameters, 
                                                    dm = 1e-4, drad = 1e-4)

    print(f" After fine calibration 1: {openptv_camera_calibration.ext_par =}, {openptv_camera_calibration.int_par = }")

    xy_optv = openptv_project_XYZ_on_camera(np.vstack([X.flat,Y.flat,Z.flat]).T, openptv_camera_calibration, control_parameters)
    axis[int(c/2),c%2].plot(xy_optv[:,0],xy_optv[:,1],'+',c='magenta')

    

    # let some parameters be fixed to change:
    orient_parameters.ccflag=0
    orient_parameters.xhflag=0
    orient_parameters.yhflag=0
    orient_parameters.scxflag=1

    residuals, targ_ix, err_est = full_calibration(openptv_camera_calibration, all_known,
                                                    targs, control_parameters, orient_parameters, 
                                                    dm = 1e-11, drad = 1e-11)


    xy_optv = openptv_project_XYZ_on_camera(np.vstack([X.flat,Y.flat,Z.flat]).T, openptv_camera_calibration, control_parameters)
    axis[int(c/2),c%2].plot(xy_optv[:,0],xy_optv[:,1],'.',c='magenta')

    

# fig.show()
# Out:
# No addpar file found. Using default values for radial distortion
# (351.70698953, -20.06356326, 1144.55602304, 0.18701021, 0.20874593, -0.03370383, [[ 0.97773598,  0.03296593,  0.20723322], [ 0.00539743,  0.98330481, -0.18188599], [-0.20976946,  0.17895501,  0.96123456]]) (-0.1093, 0.0828, 41.)
#  Before: openptv_camera_calibration.ext_par =rec.array((0., 0., 1000., 0., 0., 0., [[ 1., -0.,  0.], [ 0.,  1., -0.], [ 0.,  0.,  1.]]),
#           dtype=[('x0', '<f8'), ('y0', '<f8'), ('z0', '<f8'), ('omega', '<f8'), ('phi', '<f8'), ('kappa', '<f8'), ('dm', '<f8', (3, 3))]), openptv_camera_calibration.int_par = rec.array((0., 0., 41.),
#           dtype=[('xh', '<f8'), ('yh', '<f8'), ('cc', '<f8')])
# Coefficients (beta): [ 2.13352479e+02 -6.53225740e+00  1.68101189e+02  1.63109078e-01
#   1.25230621e-01  1.72191640e-02]
# Residuals: []
# rank: 6
# singular_values: None
# Coefficients (beta): [ 1.28501204e+02 -7.55873181e+00  2.93940850e+01  1.58095520e-02
#   7.50823517e-02 -4.61378765e-02]
# Residuals: []
# rank: 6
# singular_values: None
# Coefficients (beta): [ 9.66841794e+00 -5.85079341e+00 -1.18022900e+01  5.39264247e-03
#   5.17594475e-03 -4.15333505e-03]
# Residuals: []
# rank: 6
# singular_values: None
# Coefficients (beta): [-2.16665333e-01  9.53776099e-02  1.75029810e-02 -4.37601184e-05
#  -1.07054052e-04  1.06831406e-05]
# Residuals: []
# rank: 6
# singular_values: None
# Coefficients (beta): [ 3.21602785e-04  2.11511908e-04 -1.61590978e-04 -1.81051885e-07
#   3.35980779e-07 -6.99748401e-09]
# Residuals: []
# rank: 6
# singular_values: None
#  After raw calibration: openptv_camera_calibration.ext_par =rec.array((351.30575756, -19.8461935, 1185.71032565, 0.18426733, 0.2053822, -0.03306137, [[ 0.97844812,  0.03236063,  0.20394134], [ 0.00485125,  0.98376873, -0.17937547], [-0.20643582,  0.17649896,  0.96240967]]),
#           dtype=[('x0', '<f8'), ('y0', '<f8'), ('z0', '<f8'), ('omega', '<f8'), ('phi', '<f8'), ('kappa', '<f8'), ('dm', '<f8', (3, 3))]), openptv_camera_calibration.int_par = rec.array((0., 0., 41.),
#           dtype=[('xh', '<f8'), ('yh', '<f8'), ('cc', '<f8')])
# Coefficients (beta): [-2.11038134e-06 -2.10776019e-06  8.67057751e-07  1.87881726e-09
#  -2.25649322e-09 -1.76146622e-10 -6.61537791e-22 -1.91867713e-23
#  -1.29585678e-23  2.72687517e-19  7.00173653e-17  6.50002585e-15
#  -6.38285549e-20  1.08772153e-19 -2.29520005e-20 -3.07283655e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
#  After fine calibration 1: openptv_camera_calibration.ext_par =rec.array((351.30575545, -19.8461956, 1185.71032651, 0.18426733, 0.2053822, -0.03306137, [[ 0.97844812,  0.03236063,  0.20394134], [ 0.00485125,  0.98376873, -0.17937547], [-0.20643581,  0.17649896,  0.96240967]]),
#           dtype=[('x0', '<f8'), ('y0', '<f8'), ('z0', '<f8'), ('omega', '<f8'), ('phi', '<f8'), ('kappa', '<f8'), ('dm', '<f8', (3, 3))]), openptv_camera_calibration.int_par = rec.array((0., 0., 41.),
#           dtype=[('xh', '<f8'), ('yh', '<f8'), ('cc', '<f8')])
# Coefficients (beta): [-4.64577228e-01 -1.72299679e-02 -1.04106023e+00  1.87894273e-04
#  -2.27024371e-04  5.01261857e-07 -6.12468152e-22 -2.43864117e-23
#  -1.80484168e-23  3.39938506e-19  7.28556796e-17  6.64852358e-15
#  -2.95426838e-20  1.49733628e-19 -2.28023237e-03 -3.08769810e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.73280187e-01  1.96390940e-01 -8.00560739e-02 -1.77291537e-04
#   1.86575672e-04  1.65047773e-05 -6.54372608e-22 -2.28202865e-23
#  -1.96232516e-23  2.66265187e-19  6.90771307e-17  6.43146019e-15
#  -3.38448924e-20  1.59764000e-19  2.22606537e-03 -3.09000398e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.22961658e-03 -1.78910041e-01 -3.30548231e-02  1.80704046e-04
#  -8.68846914e-07 -2.84068206e-05 -6.52294290e-22 -2.26340034e-23
#  -2.00223975e-23  2.69322526e-19  6.95025809e-17  6.48375943e-15
#  -3.45219833e-20  1.58965786e-19 -2.23299761e-03 -3.06779065e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.25942443e-02 -1.14523605e-02 -4.78173537e-02  1.88706021e-05
#  -1.26154320e-05 -1.76667706e-06 -6.73363371e-22 -2.24753135e-23
#  -2.08298719e-23  2.26400059e-19  6.67839594e-17  6.29079314e-15
#  -3.51724952e-20  1.63007426e-19  2.18768660e-03 -3.07439012e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.06906251e-01 -3.64975484e-02  1.71992797e-01  5.61602332e-06
#  -2.31438461e-04  1.05037080e-05 -6.09434797e-22 -2.39361277e-23
#  -1.89628351e-23  3.55536279e-19  7.43100624e-17  6.77654790e-15
#  -3.27750726e-20  1.53427251e-19 -2.07642177e-03 -3.08094272e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.98610993e-01  1.96400438e-01 -7.77182886e-02 -1.77971367e-04
#   2.10781790e-04  1.63125594e-05 -6.46743985e-22 -2.30572016e-23
#  -1.96035072e-23  2.81890634e-19  6.99407332e-17  6.48504400e-15
#  -3.30445298e-20  1.59398381e-19  2.02445756e-03 -3.09098531e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-9.38020583e-02 -9.13362059e-02 -6.90139051e-02  1.00600825e-04
#  -7.89979925e-05 -1.05466244e-05 -6.79049716e-22 -2.26859610e-23
#  -2.06547689e-23  2.22715647e-19  6.71016968e-17  6.34371270e-15
#  -3.55202771e-20  1.62947662e-19 -2.10140920e-03 -3.07894196e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.47103266e-01 -4.50474777e-02  3.64647806e-02  3.71516971e-05
#  -1.48547303e-04  2.46668916e-06 -6.69044250e-22 -2.33466214e-23
#  -2.05748396e-23  2.42861146e-19  6.80081893e-17  6.37986662e-15
#  -3.44741280e-20  1.62023867e-19  2.10884533e-03 -3.09239604e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.41757239e-02 -3.68433454e-02  3.56283815e-02  3.02346353e-05
#   5.44615107e-06 -4.78598447e-06 -6.49098957e-22 -2.37035406e-23
#  -2.00470095e-23  2.81618998e-19  7.03926839e-17  6.54655142e-15
#  -3.32268596e-20  1.58962002e-19 -2.06951263e-03 -3.08302710e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.08499723e-02  5.21265793e-02 -2.97432191e-02 -4.61023200e-05
#  -2.73515921e-06  7.40055484e-06 -6.68334185e-22 -2.35121850e-23
#  -2.05258173e-23  2.44422908e-19  6.80780145e-17  6.38248917e-15
#  -3.37500364e-20  1.62206581e-19  2.03287014e-03 -3.09238234e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 3.81141879e-02 -2.02583020e-01  1.17011275e-02  1.96305025e-04
#   2.70079780e-05 -3.13837934e-05 -6.39201322e-22 -2.37178964e-23
#  -2.01703680e-23  2.96356792e-19  7.10526827e-17  6.58130429e-15
#  -3.28642943e-20  1.57294955e-19 -1.98303771e-03 -3.06944177e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.95691024e-01  2.17889107e-01 -1.18705569e-01 -1.91585218e-04
#   3.11834891e-04  1.09086210e-05 -6.88414803e-22 -2.23398174e-23
#  -2.13719243e-23  1.95708437e-19  6.51085067e-17  6.19088211e-15
#  -3.40502478e-20  1.66127314e-19  1.91598803e-03 -3.06832261e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.19987649e-01  2.42567898e-01  2.71459811e-01 -2.83966032e-04
#  -2.54003613e-04  5.68016420e-05 -6.10195793e-22 -2.36727729e-23
#  -1.79730718e-23  3.60356589e-19  7.47052685e-17  6.80213194e-15
#  -3.32164389e-20  1.53167435e-19 -1.75764721e-03 -3.10195025e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.10256150e-01 -2.57739769e-01 -1.22333148e-01  2.73094651e-04
#   1.19645058e-04 -4.75060418e-05 -6.29742391e-22 -2.32043423e-23
#  -1.91624720e-23  3.11565333e-19  7.15558059e-17  6.58530032e-15
#  -3.25404551e-20  1.55318289e-19  1.71491127e-03 -3.07894868e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.18125207e-01 -8.11635743e-02 -1.91698933e-01  1.10321744e-04
#  -1.72762968e-04 -6.16466382e-06 -7.27360283e-22 -2.23346414e-23
#  -2.24991941e-23  1.32256106e-19  6.22173840e-17  6.05220172e-15
#  -3.78563183e-20  1.70406631e-19 -1.94020544e-03 -3.07305455e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 6.50515087e-02  6.26153170e-02  1.25953141e-01 -8.19518615e-05
#   3.97081525e-05  9.81326989e-06 -6.71030751e-22 -2.31891386e-23
#  -2.07351234e-23  2.38063142e-19  6.76986666e-17  6.35954828e-15
#  -3.43713183e-20  1.62828250e-19  2.06578745e-03 -3.08899573e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-8.46087858e-02 -1.33721631e-01 -6.22506235e-02  1.40559898e-04
#  -7.30982226e-05 -1.79253334e-05 -6.92778838e-22 -2.30877338e-23
#  -2.17243972e-23  1.96080648e-19  6.56829046e-17  6.26208711e-15
#  -3.55440963e-20  1.65641183e-19 -2.12761760e-03 -3.07148400e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.13596272e-01  7.33718339e-02  1.92099720e-01 -1.02523351e-04
#   1.68344154e-04  5.00964134e-06 -5.94451604e-22 -2.38358898e-23
#  -1.85836900e-23  3.76010847e-19  7.49353624e-17  6.78229144e-15
#  -3.12267238e-20  1.51379137e-19  2.35756049e-03 -3.08202076e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.79559227e-01  1.64499709e-01 -1.39535637e-01 -1.36803567e-04
#   2.03367816e-04  1.14468758e-05 -6.59581178e-22 -2.23084121e-23
#  -2.02944795e-23  2.54051489e-19  6.85289015e-17  6.41533990e-15
#  -3.44862691e-20  1.61328131e-19 -2.47221642e-03 -3.06845100e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-8.31543345e-02 -1.40028037e-01 -5.05998138e-02  1.45164545e-04
#  -7.40837035e-05 -1.79750010e-05 -6.74514132e-22 -2.21528222e-23
#  -2.08559956e-23  2.21434615e-19  6.64178019e-17  6.26448019e-15
#  -3.58539700e-20  1.62650748e-19  2.43092369e-03 -3.07023223e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-8.84846894e-02 -7.19043666e-02  6.34424471e-02  5.93016191e-05
#  -9.88288879e-05 -3.39249490e-06 -6.47844686e-22 -2.28377691e-23
#  -2.03943394e-23  2.76831761e-19  6.98622231e-17  6.50396352e-15
#  -3.46288687e-20  1.58929339e-19 -2.38882402e-03 -3.06576636e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.69841558e-01 -7.80676908e-03  4.43239897e-02 -1.17079410e-06
#  -2.65103973e-04  1.49153358e-05 -6.48944296e-22 -2.37773414e-23
#  -2.04012321e-23  2.77926786e-19  6.97458748e-17  6.47487433e-15
#  -3.37106781e-20  1.59624564e-19  2.36228854e-03 -3.08540280e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 3.04291203e-01  2.59796842e-01  6.96490336e-02 -2.63904164e-04
#   2.84712469e-04  2.66115695e-05 -6.21917703e-22 -2.33286377e-23
#  -1.86594532e-23  3.30274079e-19  7.28834690e-17  6.68735651e-15
#  -3.32097269e-20  1.54767535e-19 -2.25987999e-03 -3.09079466e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.41286107e-01 -2.04542747e-02 -2.37857732e-01  5.87547999e-05
#  -8.89692224e-05 -5.07422376e-06 -7.34868229e-22 -2.20820899e-23
#  -2.21266657e-23  1.18974228e-19  6.12500198e-17  5.97050174e-15
#  -3.77076331e-20  1.71518439e-19  2.00558848e-03 -3.08931188e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.79399239e-01 -6.03158816e-02  5.13952724e-02  5.18682958e-05
#   2.53248899e-04 -2.29685378e-05 -6.83331538e-22 -2.19797609e-23
#  -2.08909677e-23  2.10260251e-19  6.63013010e-17  6.29191223e-15
#  -3.56228544e-20  1.64005978e-19 -1.87647511e-03 -3.06694743e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-3.85806779e-01 -2.51490846e-01  1.01826571e-01  2.26448405e-04
#  -3.95453709e-04 -1.33021366e-05 -6.40676687e-22 -2.34731302e-23
#  -2.05276411e-23  2.89541459e-19  7.03126755e-17  6.50968724e-15
#  -3.42886267e-20  1.59013109e-19  1.91417238e-03 -3.07242137e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 3.92011009e-02  2.22500542e-01 -6.02565347e-02 -2.06967341e-04
#   5.73080347e-05  2.87198289e-05 -6.91341149e-22 -2.32106299e-23
#  -2.12661161e-23  2.02536969e-19  6.60624358e-17  6.28298302e-15
#  -3.45732443e-20  1.65983530e-19 -2.00283140e-03 -3.08283594e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 7.71850694e-02  1.17708339e-01 -3.30985434e-02 -1.09093242e-04
#   8.36460317e-05  1.17884304e-05 -7.11214278e-22 -2.26107416e-23
#  -2.14635626e-23  1.65365096e-19  6.38570747e-17  6.13301486e-15
#  -3.55539208e-20  1.68520755e-19  1.97844221e-03 -3.09471798e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.94033419e-01 -1.31063382e-01  1.87317464e-01  9.53953542e-05
#  -3.20504967e-04  4.22051630e-06 -6.38734825e-22 -2.43870804e-23
#  -1.92813967e-23  3.09332825e-19  7.21271937e-17  6.66025711e-15
#  -3.32375141e-20  1.56299689e-19 -1.85835700e-03 -3.10078301e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 4.31960050e-01  3.71739061e-02 -1.67771338e-01 -6.23704035e-06
#   4.44706450e-04 -2.58924644e-05 -6.79571859e-22 -2.29028907e-23
#  -2.09026191e-23  2.17057281e-19  6.64662636e-17  6.28265579e-15
#  -3.31200107e-20  1.64090018e-19  1.80609328e-03 -3.07579601e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 9.55542764e-04  3.01579195e-02  1.04778394e-01 -4.68429472e-05
#  -1.87247394e-05  8.60511990e-06 -6.36324774e-22 -2.30193862e-23
#  -1.92917041e-23  3.01213444e-19  7.12510541e-17  6.58698917e-15
#  -3.38377400e-20  1.56911308e-19 -1.71414372e-03 -3.07937336e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 4.15401441e-03 -1.24976552e-01 -2.25360160e-01  1.59837157e-04
#   4.38821063e-05 -2.55845084e-05 -7.23623987e-22 -2.17455479e-23
#  -2.24910200e-23  1.30526669e-19  6.16038072e-17  5.98354218e-15
#  -3.70292955e-20  1.70452358e-19  1.52468814e-03 -3.06389871e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-8.72055197e-02  1.21812216e-01  1.48943562e-01 -1.44404987e-04
#  -1.08093593e-04  2.64668155e-05 -6.77186575e-22 -2.26486486e-23
#  -2.08162596e-23  2.25596236e-19  6.72073395e-17  6.34642670e-15
#  -3.55974606e-20  1.64140077e-19 -1.42936858e-03 -3.08063414e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.77652773e-01  1.10370400e-01  2.73814131e-01 -1.52777947e-04
#   1.19557835e-04  1.42307151e-05 -5.48538909e-22 -2.39558042e-23
#  -1.63242963e-23  4.64000073e-19  7.96959693e-17  7.06586908e-15
#  -2.98052099e-20  1.43909337e-19  1.71887177e-03 -3.09545712e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-9.02338184e-02  3.69114903e-02 -2.36286623e-01  3.32597764e-06
#  -3.85940497e-05  3.73711767e-06 -6.69034065e-22 -2.25603894e-23
#  -1.95785848e-23  2.42985910e-19  6.81347376e-17  6.39883582e-15
#  -3.52317676e-20  1.60815360e-19 -1.97250220e-03 -3.09005285e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.71908728e-02 -2.13837542e-01  1.43100269e-02  2.06621790e-04
#   1.58252415e-05 -3.16944031e-05 -6.37053109e-22 -2.29002683e-23
#  -1.93997684e-23  2.95034139e-19  7.05586280e-17  6.52071785e-15
#  -3.33149771e-20  1.56255377e-19  2.02900489e-03 -3.07922736e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.95242168e-01  9.01543311e-02  1.36051468e-01 -1.12144798e-04
#  -2.09243303e-04  2.84635805e-05 -6.00660845e-22 -2.40138529e-23
#  -1.81390413e-23  3.73286655e-19  7.52983634e-17  6.83470279e-15
#  -3.23783148e-20  1.51843697e-19 -1.96610486e-03 -3.09136983e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.00408842e-02 -1.16830266e-01 -1.18914438e-01  1.34030179e-04
#   2.40520307e-07 -1.93534445e-05 -6.45097194e-22 -2.35990441e-23
#  -1.98238245e-23  2.86518891e-19  7.02729317e-17  6.50997674e-15
#  -3.29924102e-20  1.57929760e-19  1.86927031e-03 -3.08668638e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-3.90167986e-03 -5.48638366e-02 -3.80117352e-02  6.00394318e-05
#   1.94456553e-06 -9.09704676e-06 -6.57752713e-22 -2.33566240e-23
#  -2.04114335e-23  2.62925539e-19  6.92647603e-17  6.47296375e-15
#  -3.39451531e-20  1.60261025e-19 -1.90082940e-03 -3.07689102e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 3.29209306e-01  2.06447975e-01  6.93015203e-02 -2.12334773e-04
#   3.05945726e-04  1.41322734e-05 -6.15637073e-22 -2.29898110e-23
#  -1.87270591e-23  3.37228029e-19  7.27887644e-17  6.64803676e-15
#  -3.25583030e-20  1.54879327e-19  2.02347625e-03 -3.08463659e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.93818545e-01 -6.37128055e-03 -4.47646649e-02  1.33243391e-05
#  -1.75277990e-04  9.07807918e-06 -6.56624737e-22 -2.27839630e-23
#  -1.95921192e-23  2.66528744e-19  6.94521397e-17  6.48170201e-15
#  -3.49794657e-20  1.58785154e-19 -2.12036261e-03 -3.08514962e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 9.61869501e-02 -6.83695465e-02 -2.11810867e-02  7.09524637e-05
#   9.33049355e-05 -1.71138370e-05 -6.49513592e-22 -2.27380933e-23
#  -1.97238107e-23  2.73959151e-19  6.94366794e-17  6.45332358e-15
#  -3.38603826e-20  1.58760809e-19  2.14047538e-03 -3.08044220e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-9.66591756e-02  2.08363101e-01  9.52072271e-02 -2.20357197e-04
#  -1.03558909e-04  3.92018389e-05 -6.36592509e-22 -2.30135234e-23
#  -1.88213764e-23  3.08132378e-19  7.18225326e-17  6.62803695e-15
#  -3.44622540e-20  1.56878848e-19 -2.11008932e-03 -3.09241442e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.60752004e-02 -4.64235989e-01 -1.25275595e-01  4.74781800e-04
#   3.31515897e-05 -7.24817479e-05 -6.41994512e-22 -2.29741194e-23
#  -2.00358656e-23  2.83402661e-19  6.98042962e-17  6.47022001e-15
#  -3.34901539e-20  1.56868102e-19  2.07468953e-03 -3.06330806e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.75237321e-01 -6.10493056e-02 -1.40715522e-01  8.26959236e-05
#  -1.40728833e-04 -4.36063236e-06 -7.15503539e-22 -2.25097171e-23
#  -2.28608094e-23  1.49694526e-19  6.29670439e-17  6.09070702e-15
#  -3.63163420e-20  1.69361502e-19 -2.24845355e-03 -3.05952102e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.55259784e-02  3.82017496e-01  2.56851134e-01 -4.16131717e-04
#  -2.24529730e-05  6.31896048e-05 -6.36023128e-22 -2.36222830e-23
#  -1.93921593e-23  3.04462524e-19  7.12336249e-17  6.56482112e-15
#  -3.33890777e-20  1.58176963e-19  2.44004698e-03 -3.10121782e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.35621652e-02 -3.34808525e-02 -4.77298792e-02  4.03498357e-05
#  -4.62062196e-06 -5.51022830e-06 -6.57051720e-22 -2.34522140e-23
#  -1.97567618e-23  2.69791866e-19  6.98381532e-17  6.51638947e-15
#  -3.39013241e-20  1.59546872e-19 -2.48640032e-03 -3.08945130e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.33782306e-01  4.82386265e-02 -7.59661727e-03 -4.52315408e-05
#   1.30405401e-04 -9.38236923e-07 -6.52674434e-22 -2.31546416e-23
#  -1.96526963e-23  2.71971477e-19  6.94662045e-17  6.45948286e-15
#  -3.33704665e-20  1.59432062e-19  2.50989262e-03 -3.09189403e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 8.83866916e-02 -1.10049369e-01 -3.36551210e-02  1.13656322e-04
#   8.66390825e-05 -2.19582281e-05 -6.50317616e-22 -2.27840343e-23
#  -1.97988049e-23  2.74580830e-19  6.98434110e-17  6.50690854e-15
#  -3.39996009e-20  1.58548223e-19 -2.50530008e-03 -3.07314781e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.29739578e-01  9.14720754e-02  1.15123443e-01 -1.09262979e-04
#  -1.42600597e-04  2.42325908e-05 -6.17510569e-22 -2.34877552e-23
#  -1.87080910e-23  3.38602153e-19  7.30125872e-17  6.66743307e-15
#  -3.31444928e-20  1.54675773e-19  2.56967838e-03 -3.09476391e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.17094187e-01  4.09113790e-02  1.27118697e-01 -6.16743337e-05
#  -1.34748498e-04  1.61008719e-05 -5.75701109e-22 -2.46134303e-23
#  -1.71852733e-23  4.25126211e-19  7.82628584e-17  7.01961053e-15
#  -3.08860228e-20  1.47791812e-19 -2.49048165e-03 -3.10169867e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.03435834e-01  5.25901514e-02 -1.09848847e-01 -3.20450396e-05
#   2.16806845e-04 -6.61624466e-06 -6.13094765e-22 -2.34948247e-23
#  -1.80641702e-23  3.48410441e-19  7.36205706e-17  6.70668680e-15
#  -3.20587316e-20  1.52994272e-19  2.43440469e-03 -3.09902844e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.24972629e-01 -8.15956582e-02 -6.72395216e-02  9.13477444e-05
#   1.29015144e-04 -2.14767207e-05 -6.22652978e-22 -2.27776258e-23
#  -1.87660525e-23  3.26632893e-19  7.26267375e-17  6.66979219e-15
#  -3.32389202e-20  1.54769397e-19 -2.45614577e-03 -3.07537815e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-3.67241585e-01 -3.06484620e-01 -7.54327801e-02  3.10809290e-04
#  -3.44979528e-04 -2.57989445e-05 -6.59108417e-22 -2.32119406e-23
#  -2.07017902e-23  2.58300287e-19  6.87171309e-17  6.41634970e-15
#  -3.50839741e-20  1.60472010e-19  2.34465986e-03 -3.07796506e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 3.55690402e-01  2.09287446e-01 -2.80299128e-02 -1.98527466e-04
#   3.50633953e-04  9.91769545e-06 -6.61762963e-22 -2.23432004e-23
#  -2.06983887e-23  2.48521265e-19  6.82443640e-17  6.40043850e-15
#  -3.45509517e-20  1.62671088e-19 -2.31282406e-03 -3.06023467e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-3.09816218e-01 -1.51148157e-01  1.37030158e-01  1.23400449e-04
#  -3.26287511e-04 -7.67118590e-07 -6.10393243e-22 -2.39123654e-23
#  -1.89841809e-23  3.49360268e-19  7.35762373e-17  6.70347875e-15
#  -3.25104358e-20  1.52872442e-19  2.38150986e-03 -3.08472674e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.57787288e-01  1.65849063e-01 -8.11173401e-02 -1.47744644e-04
#   1.71447348e-04  1.29896269e-05 -6.51565325e-22 -2.30334661e-23
#  -1.98582200e-23  2.73319887e-19  6.97496505e-17  6.49765716e-15
#  -3.38881811e-20  1.59191547e-19 -2.44200656e-03 -3.07664471e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 7.80757937e-02  3.49913107e-03  2.03095303e-02 -6.43907295e-06
#   7.04876354e-05 -3.61977344e-06 -6.34284860e-22 -2.30282686e-23
#  -1.93994599e-23  3.01936164e-19  7.09129296e-17  6.53832890e-15
#  -3.32774488e-20  1.56995840e-19  2.48211431e-03 -3.08313796e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.24472558e-01 -2.97761512e-02 -2.53993648e-02  3.26657477e-05
#  -1.14485005e-04  1.25155475e-06 -6.54807315e-22 -2.31138184e-23
#  -2.00810670e-23  2.68907929e-19  6.96175047e-17  6.49569852e-15
#  -3.44018266e-20  1.59686688e-19 -2.53698131e-03 -3.07993025e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 9.63214508e-02  1.03745014e-01  6.51843568e-02 -1.11922981e-04
#   8.25535468e-05  1.05129772e-05 -6.25063814e-22 -2.33761933e-23
#  -1.91265945e-23  3.19617774e-19  7.19173750e-17  6.59938832e-15
#  -3.22387325e-20  1.56396842e-19  2.60951769e-03 -3.08909347e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 8.33150853e-02 -6.73232064e-02 -4.74068241e-02  7.43632728e-05
#   8.60080676e-05 -1.45748867e-05 -6.35330792e-22 -2.28125287e-23
#  -1.92856327e-23  3.02058439e-19  7.12678823e-17  6.58847983e-15
#  -3.36601773e-20  1.56338307e-19 -2.62501422e-03 -3.07200968e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-3.29616224e-02 -2.62585070e-01 -1.27540682e-01  2.77247218e-04
#  -1.55878110e-05 -4.13014755e-05 -6.63435705e-22 -2.22324703e-23
#  -2.13506581e-23  2.37679587e-19  6.71317146e-17  6.30033150e-15
#  -3.53536089e-20  1.63064437e-19  2.54249874e-03 -3.05701100e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.72676529e-01  9.47196602e-02  1.99566943e-01 -1.26284239e-04
#  -1.99725071e-04  3.19128793e-05 -6.01416219e-22 -2.38210542e-23
#  -1.89204432e-23  3.66256055e-19  7.47645203e-17  6.79808501e-15
#  -3.26470988e-20  1.52636957e-19 -2.41759399e-03 -3.07542460e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.15612127e-01  2.41360973e-01 -7.54516486e-02 -2.22732926e-04
#   1.32773350e-04  2.57375026e-05 -6.51852750e-22 -2.29262507e-23
#  -1.98330341e-23  2.71503152e-19  6.92898801e-17  6.43971771e-15
#  -3.36239495e-20  1.60140535e-19  2.34102784e-03 -3.08823958e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.49854120e-03  2.44700412e-02  1.99313250e-01 -5.71871228e-05
#  -4.02426865e-05  9.79708354e-06 -5.64413077e-22 -2.40366528e-23
#  -1.68473333e-23  4.41418102e-19  7.89361098e-17  7.05104021e-15
#  -3.12647311e-20  1.46060646e-19 -2.15992591e-03 -3.09111234e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.39239100e-02  2.81327076e-02 -1.09615990e-01 -9.36742164e-06
#  -4.49900134e-07  1.46796843e-06 -6.17360615e-22 -2.34861549e-23
#  -1.83768623e-23  3.38030692e-19  7.30021037e-17  6.66720593e-15
#  -3.27592528e-20  1.54166753e-19  2.04679063e-03 -3.09550765e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.64686365e-01 -1.37207643e-01 -1.00856293e-01  1.50292752e-04
#  -1.41490079e-04 -1.42057985e-05 -6.65221362e-22 -2.31931908e-23
#  -2.02107016e-23  2.54020699e-19  6.89359303e-17  6.45885885e-15
#  -3.49486549e-20  1.61033854e-19 -2.16759522e-03 -3.08603217e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.52934927e-01  8.08712606e-02  1.15484377e-01 -9.79686739e-05
#   1.25431917e-04  7.18842624e-06 -6.06108322e-22 -2.37675994e-23
#  -1.83202352e-23  3.60886858e-19  7.42834201e-17  6.74842141e-15
#  -3.16356975e-20  1.52872923e-19  2.30858662e-03 -3.09339708e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.28894403e-01 -2.65620525e-01 -4.82230564e-02  2.67218759e-04
#  -1.22031604e-04 -3.41618092e-05 -6.13359875e-22 -2.39398522e-23
#  -1.91593975e-23  3.45841934e-19  7.36849001e-17  6.73527282e-15
#  -3.23158418e-20  1.53171534e-19 -2.34856475e-03 -3.07546748e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 7.38906058e-03  1.16669482e-01 -5.35521650e-02 -1.05031538e-04
#   2.15454474e-05  1.64337461e-05 -6.48444709e-22 -2.35473966e-23
#  -2.00746514e-23  2.79424935e-19  6.98085304e-17  6.47704439e-15
#  -3.30841143e-20  1.59442176e-19  2.28448477e-03 -3.08886854e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.25744132e-01 -1.91081306e-02 -1.73765897e-01  4.71372046e-05
#  -8.64433968e-05 -1.86394119e-06 -7.36379296e-22 -2.27012369e-23
#  -2.27259067e-23  1.19084364e-19  6.16993783e-17  6.03143282e-15
#  -3.65106211e-20  1.71690121e-19 -2.48113295e-03 -3.07904151e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 3.72656143e-01  4.88842110e-02  1.43226863e-01 -7.00177628e-05
#   3.28242284e-04 -8.07103612e-06 -6.43572940e-22 -2.29473643e-23
#  -1.99139365e-23  2.80456676e-19  6.96505388e-17  6.46179064e-15
#  -3.23099579e-20  1.58534940e-19  2.71138825e-03 -3.07105010e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 7.62113292e-02  1.37982170e-01  4.23414290e-02 -1.41282854e-04
#   6.85737273e-05  1.70696287e-05 -6.33112241e-22 -2.24352453e-23
#  -1.91754060e-23  3.04312371e-19  7.13278998e-17  6.58877461e-15
#  -3.44161705e-20  1.56929940e-19 -2.67668631e-03 -3.07083872e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-2.53077239e-01 -3.25943226e-01 -1.33484097e-01  3.39659689e-04
#  -2.25486381e-04 -3.77663538e-05 -6.82057983e-22 -2.25220491e-23
#  -2.14555624e-23  2.06886315e-19  6.56388931e-17  6.21872094e-15
#  -3.52947821e-20  1.63863283e-19  2.53904232e-03 -3.06456242e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 1.34020090e-02  3.31953240e-01  2.31785628e-01 -3.62877436e-04
#  -2.11646826e-05  5.57091797e-05 -6.08942291e-22 -2.38543897e-23
#  -1.84157008e-23  3.58315307e-19  7.44987416e-17  6.78742309e-15
#  -3.19805390e-20  1.53791066e-19 -2.36855712e-03 -3.09246811e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 7.68612693e-02  4.71250910e-02  6.89687653e-02 -5.75348488e-05
#   6.12061820e-05  4.32302196e-06 -5.75579628e-22 -2.38341924e-23
#  -1.70340662e-23  4.18459677e-19  7.73580589e-17  6.92800153e-15
#  -3.11247158e-20  1.47888924e-19  2.44511334e-03 -3.09906479e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 2.45815247e-02 -1.94527537e-01 -1.51189133e-01  2.15666838e-04
#   4.61345077e-05 -3.45109551e-05 -6.22953287e-22 -2.31109380e-23
#  -1.90440948e-23  3.23939766e-19  7.24392794e-17  6.65731448e-15
#  -3.33669248e-20  1.54308871e-19 -2.55664387e-03 -3.07231090e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-1.66196307e-01 -6.39375073e-02 -1.16043057e-01  8.09645512e-05
#  -1.37508712e-04 -4.75409888e-06 -6.82478665e-22 -2.27381684e-23
#  -2.11132613e-23  2.13480335e-19  6.61714862e-17  6.25692982e-15
#  -3.53561803e-20  1.63986559e-19  2.42034429e-03 -3.08062436e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [ 5.43152291e-02  8.77232625e-02  1.05270890e-01 -1.03248340e-04
#   3.41318749e-05  1.34164470e-05 -6.39341246e-22 -2.34213877e-23
#  -1.96852681e-23  2.98144324e-19  7.11990673e-17  6.59045950e-15
#  -3.32603975e-20  1.58165761e-19 -2.32557489e-03 -3.08159681e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Coefficients (beta): [-5.07942681e-02 -3.31878161e-02 -1.06301501e-01  5.00110127e-05
#  -2.86177851e-05 -5.49722332e-06 -6.88537403e-22 -2.27530919e-23
#  -2.11370019e-23  2.02515119e-19  6.56681325e-17  6.23184282e-15
#  -3.52144459e-20  1.64702533e-19  2.21901456e-03 -3.08305017e-20]
#                  Residuals: []
#                  singular_values: None
#                  rank: 16
#
# Residuals = None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 91
#      88 orient_parameters.yhflag=0
#      89 orient_parameters.scxflag=1
# ---> 91 residuals, targ_ix, err_est = full_calibration(openptv_camera_calibration, all_known,
#      92                                                 targs, control_parameters, orient_parameters,
#      93                                                 dm = 1e-11, drad = 1e-11)
#      96 xy_optv = openptv_project_XYZ_on_camera(np.vstack([X.flat,Y.flat,Z.flat]).T, openptv_camera_calibration, control_parameters)
#      97 axis[int(c/2),c%2].plot(xy_optv[:,0],xy_optv[:,1],'.',c='magenta')
#
# File ~/Documents/repos/openptvpy/openptv-python/openptv_python/orientation.py:842, in full_calibration(cal, ref_pts, img_pts, cparam, orient_par, dm, drad)
#     839 if residuals is None:
#     840     # free(residuals)
#     841     print(f"Residuals = {residuals}")
# --> 842     raise ValueError("Orientation iteration failed, need better setup.")
#     844 ret = np.empty((len(img_pts), 2))
#     845 used = np.empty(len(img_pts), dtype=np.int_)
#
# ValueError: Orientation iteration failed, need better setup.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
