# %%
import pandas as pd
import plotly.express as px

# %%
xyz = pd.read_csv('/home/user/Dropbox/Open_Pro_My_PTV/rbc300/alex_calibration/res/rt_is.123456789',delim_whitespace=True,skiprows=1,names=['id','x','y','z','i1','i2','i3','i4'])
xyz
# Out:
# /tmp/ipykernel_824611/2910440131.py:1: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#       id        x        y        z   i1   i2   i3   i4
# 0      1  150.016  149.968  214.619  254  244  201  271
# 1      2  164.967  149.986  214.506  252  243  202  272
# 2      3  135.099  149.939  214.644  255  245  200  270
# 3      4  150.020  135.014  214.541  275  317  224  295
# 4      5  150.017  164.924  214.615  234  218  181  252
# ..   ...      ...      ...      ...  ...  ...  ...  ...
# 459  460   58.017   65.205  242.946   -1  462   -1  397
# 460  461   30.108  122.750  219.713   -1   -1  237  309
# 461  462  106.741   81.451  247.167   -1  425   -1  373
# 462  463  169.814  297.085  211.545   37   -1   -1   42
# 463  464   56.235  112.527  299.241  302   -1   -1  326
#
# [464 rows x 8 columns]

# %%
import numpy as np
np.abs(xyz['z'] - 274) > 10
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 459    True
# 460    True
# 461    True
# 462    True
# 463    True
# Name: z, Length: 464, dtype: bool

# %%
px.scatter_3d(x=xyz['x'], y=xyz['y'], z=xyz['z'], color=xyz['id']).show()

# %%
tmp = xyz['z']-274

import plotly.graph_objects as go

fig = go.Figure(data=[go.Histogram(x=tmp, xbins=dict(start=-2, end=2, size=0.1))])
fig.show()
